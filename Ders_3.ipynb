# %% [markdown]
# <a href="https://colab.research.google.com/github/robokidkod/ML4Kids/blob/master/Ders_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Ortamı Kurulumu ve ilk Kod
# Python betiği, python sanal makinesi ve yorumlayıcı* oyumlanan ve derlenen programlama dillerine örnek verilebilir
# Optimum Araç: Anaconda "Dünyanın en popüler ver bilmi platformu" 3 sürümü mevcut
# IDE Spyder
# R Studio
# q Python (Etkileşimli kabuk) alt text
#
#
# Jupyter Notebook
# Google colaboration
# Kullanılacak kütüphaneler
# Numpy
# Pandas
# matplot
# Google Colaboration Kullanımı
#
# Google hesabı olmalı
# https://colab.research.google.com/notebooks/intro.ipynb adresine girilir. Google hesabıyla giriş yapılır.
# ![alt text](https://drive.google.com/uc?id=1_iHsLiQmCess6Jwvki3F6tX-b71e3eRd)
# #Link eklemek için open kısmı uc ile değiştirlir.

# %%
from IPython.display import Image
Image('GoogleColab.png')
#Fotoğraf eklemek için bu şekilde de kullanılabilir

# %%
#ilk kodumuz
#açıklama satırı
print ("Merhaba Dünya")
print ('Merhaba Dünya')
# Out:
# Merhaba Dünya
# Merhaba Dünya

# %%
# usr/local/share/jupyter/nbextensions altına resim eklenirse bu kod kullanılabilir
# %%html
<img src='/nbextensions/GoogleColab3.png' />
# Out:
# <img src='/nbextensions/GoogleColab3.png' />
